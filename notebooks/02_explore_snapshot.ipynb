# %% [markdown]
# # Explore Monthly Power BI Snapshot
#
# ## Purpose
#
# This notebook loads the synthetic monthly Power BI export and performs initial data exploration and quality checks before analysis.

# %%
import pandas as pd

# %%
# Load the Power BI snapshot

df = pd.read_csv("../data/raw/powerbi_snapshot_2026_01.csv")

# %%
df.head()
# Out:
#     Case ID Policy Number Client Number  Outstanding Amount  \
# 0  DH000001     PET000001      CL000164               13.72
# 1  DH000002     PET000002      CL000029                8.55
# 2  DH000003     PET000003      CL000007               90.36
# 3  DH000004     PET000004      CL000190               76.82
# 4  DH000005     PET000005      CL000071              175.71
#
#   Cancellation Status Cancelling Department Cancelling Agent Snapshot Date
# 0           Cancelled      Customer Service            CS013    2026-01-31
# 1           Cancelled            Retentions           RET029    2026-01-31
# 2           Cancelled            Retentions           RET030    2026-01-31
# 3           Cancelled            Retentions           RET021    2026-01-31
# 4           Cancelled            Retentions           RET015    2026-01-31
